# %% [markdown]
# # Matplotlib: Plotting Data

# %% [markdown]
# ### Humans are visual creatures.
#
# #### Task
#
# Compare the line plot below with the list of values, and answer the following questions:
#
# 1. Are these the same or different data?
# 2. What is the *median* of this data?
# 3. What is the *max* and *min* of this data?
# 4. Are there any patterns in this data?
# 5. What's your best guess for the next value in this series?
#
# ##### a Graphical Representation of Data
#
# <img src="imgs/example_plot.png" width="300" height="350">
#
# ##### a Textual Representation of Data
# ```
# [0.5, 0.9, 1.0, 0.7, 0.2, -0.4, -0.9, -1.0, -0.8, -0.3]
# ```
# <br>
#
# Which data representation did you use to intuit these statistics?  Why?
#
# **How you present your data affects how you perceive your data. And visual charts are often much more effective at conveying patterns in data!**

# %% [markdown]
# ## Matplotlib: A Plotting Package in Python
#
# Matplotlib is one of *many* different options for making plots and charts, but its popularity often makes it the default choice, especially when making charts for paper publications.  It's so popular, that many other plotting packages use Matplotlib to make their plots!  Here's an overview of the plotting ecosystem:
#
# <img src="imgs/python_plotting_libraries.png" alternate="from https://rougier.github.io/python-visualization-landscape/landscape-colors.png"></img>
#
# The Matplotlib ecosystem is the violet part of that graph.  So many options!  In this workshop, we'll take a look at `matplotlib`, `pandas`, and `seaborn`, but if you are interested in other visual styles or aesthetics, or if you want plots that are interactive, it's worth trying out another plotting library (I can recommend `plotly`, `holoviz`, and `altair`).

# %% [markdown]
# In this notebook, we'll explore some of the plotting functions provided by the **matplotlib** package and learn how to adjust them to be more informative.
#
# #### Something to generally keep in mind
#
# **Functions Have Optional Parameters that Change Their Behavior**: Many of the plotting functions will let you modify them by adding a named parameter (e.g. `plt.hist(data, bins=20, density=True, cumulative=False)`).

# %% [markdown]
# ## Sequential Plots with the `plt.plot()` function
#
# The `plot()` function in Matplotlib is very unique; it can be used to make both line and scatter plots, and tends to be the first function people learn to use.  So let's try it out!
#
#   - **`plt.plot(data)`**: Makes a line plot, with the y axis being the values in `data`
#   - **`plt.plot(data, '.')`**: Makes a point plot, with the y axis being the values in `data`
#   - **`plt.plot(x, y)`**: Makes a line plot, with the x and y axis matching the values in x and y.
#   - **`plt.plot(x, y, '.')`**: Makes a point plot, with the y axis being the values in x and y
#     - **Note**: `x` and `y` must have the same length.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 10)
y = np.sin(x)

plt.plot(x, y, color="limegreen", linewidth=3, linestyle="--");

# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Make a line plot of this list.

# %%
data = [1, 2, 4, 2, 1]

# %%
plt.plot(data)

# %% [markdown]
# 2. Make a line plot of this data.

# %%
data = [1, 2, 4, 8, 16, 32, 64]

# %%
plt.plot(data)

# %% [markdown]
# 3. Create an array that goes from $0$ to $4\pi$ with 200 equally spaced points, and plot it.

# %%
x = np.linspace(0, 4*np.pi, 200)
plt.plot(x)

# %% [markdown]
# 4. Apply the sinusoid function on the array you created in the last exercise and plot the result.

# %%
y = np.sin(x)
plt.plot(y)

# %% [markdown]
# 5. Now plot the same data as the last exercise, but specify both the x and y axis this time:
# ```
# x = data # from 0 to 4*pi
# y = sin(data)
# ```
# <br>
#
# What is different about this plot compared to previous one?

# %%
plt.plot(x, y)

# %% [markdown]
# #### Format strings in `plt.plot()`
#
# There are actually lots of different point markers and line styles that can be used in `plt.plot()` to change how the data looks. Try out these:
#
#   - **(Some) Point Markers**: `'.'`, `'o'`, `'v'`, `'^'`, `'<'`, `'s'`, `'h'`, `'D'`, `'|'`, `'_'`
#
#   - **(Some) Line Styles**: `'-'`, `'--'`, `'-.'`, `':'`
#
#   - **(Some) Colors**: `'b'`, `'g'`, `'c'`, `'r'`, `'m'`, `'y'`, `'k'`, `'w'`

# %%
x = np.linspace(0, 2*np.pi, 10)
y = np.sin(x)

plt.plot(x, y, color=(.4, .2, .9), marker="o", linestyle="", linewidth=4)

# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Plot this data with magenta circular points:

# %%
data = np.abs(np.arange(-10, 11))

# %%
plt.plot(data, color="magenta", marker="o")

# %% [markdown]
# 2. Plot this data with a green dashed line

# %%
data = np.log(np.linspace(.1, 6, 50))

# %%
plt.plot(data, color="g", linestyle="--")

# %% [markdown]
# 3. Multiple datasets can be included in the same plot, simply by calling `plt.plot()` multiple times.  Put both the following datasets in the same plot (line or point, your choice):

# %%
x = np.linspace(0, np.pi * 4, 20)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x, y1, marker="o", linestyle="--")
plt.plot(x, y2, marker="o")

# %% [markdown]
# 4. Also plot these in the same plot:

# %%
x1 = np.linspace(0, np.pi * 4, 200)
y1 = np.sin(x1)

x2 = np.linspace(np.pi * 4, np.pi * 8, 200)
y2 = np.sin(x2)

# %%
plt.plot(x1, y1)
plt.plot(x2, y2)

# %% [markdown]
# 5. Plot each line with different markers, linestyles, but the same color:

# %%
plt.plot(x1, y1, marker="x", linestyle="-", color="navy")
plt.plot(x2, y2, marker="o", linestyle="--", color="navy")

# %% [markdown]
# ## Labeling Your Data: Adding Text
#
# Let's add some text to our plots, so people understand what the plots represent!
#
#   - **`plt.title("My Title")`**: Adds a title to the current plot
#   - **`plt.xlabel("X")`**:  Adds a label to the x axis
#   - **`plt.ylabel("Y")`**: Adds a label to the y axis
#   - **`plt.plot(data, label="My label"); plt.legend()`**:  Labels the plotted data and makes a legend with the labels.
#     - **Note**: Normally this is done on seperate lines of code.
#
#
# Example: You can combine them together and label everything!

# %%
plt.plot([1, 2, 4, 8, 16], label="Multiples of 2")
plt.plot([1, 3, 9, 27], label="Multiples of 3")
plt.title("Comparing Multiples of Integers")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc=(1, 0), fontsize=20, frameon=False);

# %% [markdown]
# ### Exercise

# %% [markdown]
# 1. Make a line plot of the data and add the title "Sin of X":

# %%
x = np.linspace(0, np.pi * 10, 200)
data = np.sin(x)

plt.plot(x, data)
plt.title("Sin of X")
# Out:
# Text(0.5, 1.0, 'Sin of X')

# %% [markdown]
# 2. Make a line plot of the data and label the Y axis "Sin of X":

# %%
x = np.linspace(0, np.pi * 10, 200)
data = np.sin(x)

plt.plot(x, data)
plt.ylabel("Sin of X")
# Out:
# Text(0, 0.5, 'Sin of X')

# %% [markdown]
# 3. Make a line plot of the data put the label "Sin of X" in a legend:

# %%
x = np.linspace(0, np.pi * 10, 200)
data = np.sin(x)

plt.plot(x, data, label="Sin of X")
plt.legend(title="Legend title")

# %% [markdown]
# 4. Make a line plot of each dataset put the labels "Sin of X" and "Cos of X" in a legend:

# %%
x = np.linspace(0, np.pi * 4, 200)
data1 = np.sin(x)
data2 = np.cos(x)

plt.plot(x, data1, label="Sin of X")
plt.plot(x, data2, label="Cos of X")

plt.legend()

# %% [markdown]
# ## Histograms
#
# When you have a lot of data, often you just want to know how much data you have and around what values your data is clustered (the data's "distribution").  This is where histograms come in; on the x axis, they show the values in your data, and on the y axis, how often those values (grouped together in "bins") occured in your dataset.
#
#   - **`plt.hist(data)`**: Make a histogram of the data
#   - **`plt.hist(data, bins=20)`**: Make a histogram of the data, specifying the number of bins
#   - **`plt.hist(data, density=True)`**: Make a probability distribution of the data (normalizes the y axis)
#   - **`plt.hist(data, cumulative=True)`**: Make a cumulative histogram of the data
#   - **`plt.hist(data, label="My data"); plt.legend()`**: label the data and put the label in a legend.
#   - **`plt.hist(data, alpha=0.5)`**: Specify how opaque (i.e. how not-transparent) the plot is, from 0-1.

# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Make a histogram of this data.  Looking at the plot, how would you describe the data's distribution (min, max, average, shape)?

# %%
n_data_points = 20
data = np.random.random(size=n_data_points)

# %%
plt.hist(data);

# %% [markdown]
# 2. Make a histogram of this data.  Looking at the plot, how would you describe the data's distribution (min, max, average, shape)?

# %%
n_data_points = 200
data = np.random.random(size=n_data_points)

# %%
plt.hist(data);

# %% [markdown]
# 3. Make a histogram of this data. Looking at the plot, how would you describe the data's distribution (min, max, average, shape)?

# %%
n_data_points = 2000
data = np.random.random(size=n_data_points)

# %%
plt.hist(data)
# Out:
# (array([235., 206., 205., 183., 211., 192., 190., 172., 197., 209.]),
#  array([0.0023701 , 0.10205791, 0.20174571, 0.30143351, 0.40112132,
#         0.50080912, 0.60049693, 0.70018473, 0.79987253, 0.89956034,
#         0.99924814]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 4. Make a histogram of this data. Looking at the plot, how would you describe the data's distribution (min, max, average, shape)?

# %%
n_data_points = 2000
data = np.random.normal(size=n_data_points)

# %%
plt.hist(data);

# %% [markdown]
# 5. Make a histogram of this data, setting the number of bins to 100, then 20, then 10, then 5 (just change the number and run the code again, looking at the graph).  How does the number of bins affect your interpreation of the data's distribution?

# %%
n_data_points = 2000
data = np.random.normal(size=n_data_points)

# %%
plt.hist(data, bins=100);

# %% [markdown]
# 6. Make a histogram of this data with normalized Y values (a probability density).  What is different about this, compared to the histogram above?

# %%
n_data_points = 200
data = np.random.normal(size=n_data_points)

# %%
plt.hist(data, density=True);

# %% [markdown]
# 7. Make a cumulative histogram of this data. What is different about this, compared to the histogram above?

# %%
n_data_points = 200
data = np.random.normal(size=n_data_points)

# %%
plt.hist(data, cumulative=True)
# Out:
# (array([  4.,  22.,  43.,  82., 124., 158., 179., 194., 199., 200.]),
#  array([-2.33402225, -1.79372321, -1.25342416, -0.71312512, -0.17282608,
#          0.36747297,  0.90777201,  1.44807106,  1.9883701 ,  2.52866914,
#          3.06896819]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 8. Make two histograms, one for each of the two datasets.  Label the data in a legend, and make the data more transparent for easier viewing (e.g. `alpha=0.4`).

# %%
n_data_points = 200
data1 = np.random.normal(0, 1, size=n_data_points)
data2 = np.random.normal(2, 0.5, size=n_data_points)

plt.hist(data1, label="Data 1")
plt.hist(data2, alpha=.4, label="Data 2");

plt.legend()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f12bb307-0323-41b8-b58a-a3dc423d7ca4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
